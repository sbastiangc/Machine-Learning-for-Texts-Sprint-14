# %% [markdown]
# ¡Hola Sebastian! Como te va?
#
# Mi nombre es Facundo Lozano! Un gusto conocerte, seré tu revisor en este proyecto.
#
# A continuación un poco sobre la modalidad de revisión que usaremos:
#
# Cuando enccuentro un error por primera vez, simplemente lo señalaré, te dejaré encontrarlo y arreglarlo tú cuenta. Además, a lo largo del texto iré haciendo algunas observaciones sobre mejora en tu código y también haré comentarios sobre tus percepciones sobre el tema. Pero si aún no puedes realizar esta tarea, te daré una pista más precisa en la próxima iteración y también algunos ejemplos prácticos. Estaré abierto a comentarios y discusiones sobre el tema.
#
# Encontrará mis comentarios a continuación: **no los mueva, modifique ni elimine**.
#
# Puedes encontrar mis comentarios en cuadros verdes, amarillos o rojos como este:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor.</b> <a class="tocSkip"></a>
#
# Exito. Todo se ha hecho de forma exitosa.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor.</b> <a class="tocSkip"></a>
#
# Observación. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor.</b> <a class="tocSkip"></a>
#
# Necesita arreglos. Este apartado necesita algunas correcciones. El trabajo no puede ser aceptado con comentarios rojos.
# </div>
#
# Puedes responder utilizando esto:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta de estudiante.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# # Aprendizaje automático para textos - ML: modelo de clasificación de reseñas

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Review General. (Iteración 2) </b> <a class="tocSkip"></a>
#
# Excelente ahora si Sebastian, muy bien implementadas las ultimas solicitudes! Ahora si el proyecto se encuentra en condiciones de ser aprobado! Felicitaciones y éxitos dentro de tu camino dentro del mundo de los datos!
#
# Saludos Sebastian!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Review General. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Sebastian, siempre me tomo este tiempo al inicio de tu proyecto para comentarte mis apreciaciones generales de esta iteración de tu entrega.
#
# Me gusta comenzar dando la bienvenida al mundo de los datos a los estudiantes, te deseo lo mejor y espero que consigas lograr tus objetivos. Personalmente me gusta brindar el siguiente consejo, "Está bien equivocarse, es normal y es lo mejor que te puede pasar. Aprendemos de los errores y eso te hará mejor programador ya que podrás descubrir cosas a medida que avances y son estas cosas las que te darán esa experiencia para ser un gran Data Scientist"
#
# Ahora si yendo a esta notebook. Felicitaciones Sebastian porque has logrado resolver todos los pasos implementando grandes lógicas, se ha notado tu manejo sobre python y las herramientas ML utilizadas. Muy bien hecho! Por otro lado hemos tenido un par de detalles que debemos corregir pero que estoy seguro que te demorara unos minutos, te he dejado los comentarios con el contexto necesario para que puedas resolverlo.
#
# Éxitos y espero con ansias a nuestra próxima iteración Sebastian!
#
# Saludos!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta Estudiante</b>
#
# Hola Facundo espero estes bien!
#
# Muchas gracias por la revisión y los comentarios, encuentra a continuación el proyecto con las correcciones solicitadas, espero que ahora todo se encuentre en orden!
#
# att: Sebastian Galindo
#
# <a class="tocSkip"></a>
# </div>

# %% [markdown]
# # Descripcipción del proyecto

# %% [markdown]
# **Nota: La ejecución de este notebook puede tardar ~ 20 mins debido a la lematización con spacy en el punto 7.3**

# %% [markdown]
# Film Junky Union, una nueva comunidad vanguardista para los aficionados de las películas clásicas, está desarrollando un sistema para filtrar y categorizar reseñas de películas. Tu objetivo es entrenar un modelo para detectar las críticas negativas de forma automática. Para lograrlo, utilizarás un conjunto de datos de reseñas de películas de IMDB con leyendas de polaridad para construir un modelo para clasificar las reseñas positivas y negativas. Este deberá alcanzar un valor F1 de al menos 0.85.

# %% [markdown]
# <h1>Contenido:<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Inicialización" data-toc-modified-id="Inicialización-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Inicialización</a></span></li><li><span><a href="#Cargar-datos" data-toc-modified-id="Cargar-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cargar datos</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span></li><li><span><a href="#Procedimiento-de-evaluación" data-toc-modified-id="Procedimiento-de-evaluación-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Procedimiento de evaluación</a></span></li><li><span><a href="#Normalización" data-toc-modified-id="Normalización-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Normalización</a></span></li><li><span><a href="#División-entrenamiento-/-prueba" data-toc-modified-id="División-entrenamiento-/-prueba-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>División entrenamiento / prueba</a></span></li><li><span><a href="#Trabajar-con-modelos" data-toc-modified-id="Trabajar-con-modelos-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Trabajar con modelos</a></span><ul class="toc-item"><li><span><a href="#Modelo-1---Constante" data-toc-modified-id="Modelo-1---Constante-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Modelo 1 - Constante</a></span></li><li><span><a href="#Modelo-2---NLTK,-TF-IDF-y-LR" data-toc-modified-id="Modelo-2---NLTK,-TF-IDF-y-LR-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Modelo 2 - NLTK, TF-IDF y LR</a></span></li><li><span><a href="#Modelo-3---spaCy,-TF-IDF-y-LR" data-toc-modified-id="Modelo-3---spaCy,-TF-IDF-y-LR-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Modelo 3 - spaCy, TF-IDF y LR</a></span></li><li><span><a href="#Modelo-4---spaCy,-TF-IDF-y-LGBMClassifier" data-toc-modified-id="Modelo-4---spaCy,-TF-IDF-y-LGBMClassifier-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Modelo 4 - spaCy, TF-IDF y LGBMClassifier</a></span></li></ul></li><li><span><a href="#Mis-reseñas" data-toc-modified-id="Mis-reseñas-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Mis reseñas</a></span><ul class="toc-item"><li><span><a href="#Modelo-2---NLTK,-TF-IDF-y-LR" data-toc-modified-id="Modelo-2---NLTK,-TF-IDF-y-LR-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Modelo 2 - NLTK, TF-IDF y LR</a></span></li><li><span><a href="#Modelo-3---spaCy,-TF-IDF-y-LR" data-toc-modified-id="Modelo-3---spaCy,-TF-IDF-y-LR-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Modelo 3 - spaCy, TF-IDF y LR</a></span></li><li><span><a href="#Modelo-4---spaCy,-TF-IDF-y-LGBMClassifier" data-toc-modified-id="Modelo-4---spaCy,-TF-IDF-y-LGBMClassifier-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Modelo 4 - spaCy, TF-IDF y LGBMClassifier</a></span></li></ul></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusiones</a></span></li></ul></div>

# %% [markdown]
# ## Inicialización

# %%
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from tqdm.auto import tqdm
import torch
import transformers
import re
import string

#importo TFIDF vectorizer 
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

#importo nltk, Logisitc regression y stopwords
import nltk
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

#importo spacy
import spacy

#importo lightgbm
from sklearn.dummy import DummyClassifier
from lightgbm import LGBMClassifier

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
# la siguiente línea proporciona gráficos de mejor calidad en pantallas HiDPI
# %config InlineBackend.figure_format = 'retina'

plt.style.use('seaborn')

# %%
# esto es para usar progress_apply, puedes leer más en https://pypi.org/project/tqdm/#pandas-integration
tqdm.pandas()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Excelentes importaciones y configuraciones!

# %% [markdown]
# ## Cargar datos

# %%
df_reviews = pd.read_csv('/datasets/imdb_reviews.tsv', sep='\t', dtype={'votes': 'Int64'})

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47331 entries, 0 to 47330
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           47331 non-null  object
#  1   title_type       47331 non-null  object
#  2   primary_title    47331 non-null  object
#  3   original_title   47331 non-null  object
#  4   start_year       47331 non-null  int64
#  5   end_year         47331 non-null  object
#  6   runtime_minutes  47331 non-null  object
#  7   is_adult         47331 non-null  int64
#  8   genres           47331 non-null  object
#  9   average_rating   47329 non-null  float64
#  10  votes            47329 non-null  Int64
#  11  review           47331 non-null  object
#  12  rating           47331 non-null  int64
#  13  sp               47331 non-null  object
#  14  pos              47331 non-null  int64
#  15  ds_part          47331 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Una carga de los datos perfecta y unos agregados de metodos para profundizar en la comprensión de los datos excelente!

# %%
# verifico si hay valores ausentes
df_reviews.isna().sum()
# Out:
# tconst             0
# title_type         0
# primary_title      0
# original_title     0
# start_year         0
# end_year           0
# runtime_minutes    0
# is_adult           0
# genres             0
# average_rating     2
# votes              2
# review             0
# rating             0
# sp                 0
# pos                0
# ds_part            0
# idx                0
# dtype: int64

# %%
# elimino los valores ausentes
df_reviews.dropna(axis=0, inplace=True)

# %%
# verifico si hay duplicados
df_reviews.duplicated().sum()
# Out:
# 0

# %%
# utilizo describe para analizar los datos
df_reviews.describe()
# Out:
#          start_year      is_adult  average_rating         votes        rating  \
# count  47329.000000  47329.000000    47329.000000  4.732900e+04  47329.000000
# mean    1989.630882      0.001733        5.998278  2.556292e+04      5.484439
# std       19.600702      0.041588        1.494289  8.367004e+04      3.473083
# min     1894.000000      0.000000        1.400000  9.000000e+00      1.000000
# 25%     1982.000000      0.000000        5.100000  8.270000e+02      2.000000
# 50%     1998.000000      0.000000        6.300000  3.197000e+03      4.000000
# 75%     2004.000000      0.000000        7.100000  1.397400e+04      9.000000
# max     2010.000000      1.000000        9.700000  1.739448e+06     10.000000
#
#                 pos           idx
# count  47329.000000  47329.000000
# mean       0.498933   6279.826808
# std        0.500004   3605.724280
# min        0.000000      0.000000
# 25%        0.000000   3162.000000
# 50%        0.000000   6300.000000
# ...

# %%
df_reviews.head(3)
# Out:
#       tconst title_type primary_title original_title  start_year end_year  \
# 0  tt0068152      movie             $              $        1971       \N
# 1  tt0068152      movie             $              $        1971       \N
# 2  tt0313150      short          '15'           '15'        2002       \N
#
#   runtime_minutes  is_adult              genres  average_rating  votes  \
# 0             121         0  Comedy,Crime,Drama             6.3   2218
# 1             121         0  Comedy,Crime,Drama             6.3   2218
# 2              25         0  Comedy,Drama,Short             6.3    184
#
#                                               review  rating   sp  pos  \
# 0  The pakage implies that Warren Beatty and Gold...       1  neg    0
# 1  How the hell did they get this made?! Presenti...       1  neg    0
# 2  There is no real story the film seems more lik...       3  neg    0
#
#   ds_part   idx
# 0   train  8335
# 1   train  8336
# 2    test  2489

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Nuevamente excelente Sebastian, en este caso profundizando sobre los duplicados y los valores nulos, bien hecho!

# %% [markdown]
# **Observación General:**
#
# La tabla de conjunto de datos de reseñas de películas de IMDB contiene 17 columnas, algunas como
# `title_type`, `primary_title`, `original_title`, `start_year`, `end_year`, `runtime_minutes`, `is_adult`ó `genres` nos permiten conocer detalles de las películas, para realizar análisis por años de lanzamiento, tiempo de duración o genero, esta información es útil para analizar segmentos de datos. Por otra parte tenemos las columnas que nos brindan información de las reseñas como `average_rating`,`votes`, `review`, `rating`, `sp`, `ds_part`, `idx` que nos indican características de las reseñas de los usuarios otorgadas a cada película.
#
#
# **Para este análisis las columnas más importantes serán `review` y `pos`.** En la primera se encuentran las reseñas de los usuarios, estas se normalizarán y se usarán métodos como Spacy y TfidfVectorizer y así convertir las palabras en características para el modelo de predicción de sentimiento. Por último `pos` es el objetivo de predicción para conocer si la reseña es positiva o negativa.
#
# - la tabla contiene 47329 reseñas.
# - el promedio calificación es 5.9.
# - la desviación estándar de la calificación promedio es 1.49.
#
# Limpieza y procesamiento de datos:
#
# - Se eliminaron valores ausentes en los datos.
# - No existen valores duplicados en los datos.

# %% [markdown]
# ## EDA

# %% [markdown]
# Veamos el número de películas y reseñas a lo largo de los años.

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 8))

ax = axs[0]

dft1 = df_reviews[['tconst', 'start_year']].drop_duplicates() \
    ['start_year'].value_counts().sort_index()
dft1 = dft1.reindex(index=np.arange(dft1.index.min(), max(dft1.index.max(), 2021))).fillna(0)
dft1.plot(kind='bar', ax=ax)
ax.set_title('Número de películas a lo largo de los años')

ax = axs[1]

dft2 = df_reviews.groupby(['start_year', 'pos'])['pos'].count().unstack()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)

dft2.plot(kind='bar', stacked=True, label='#reviews (neg, pos)', ax=ax)

dft2 = df_reviews['start_year'].value_counts().sort_index()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)
dft3 = (dft2/dft1).fillna(0)
axt = ax.twinx()
dft3.reset_index(drop=True).rolling(5).mean().plot(color='orange', label='reviews per movie (avg over 5 years)', ax=axt)

lines, labels = axt.get_legend_handles_labels()
ax.legend(lines, labels, loc='upper left')

ax.set_title('Número de reseñas a lo largo de los años')

fig.tight_layout()

# %% [markdown]
# Veamos la distribución del número de reseñas por película con el conteo exacto y KDE (solo para saber cómo puede diferir del conteo exacto)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Unas observaciones que nos permitirán comprender el trabajo que debemos realizar. Excelente.

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

ax = axs[0]
dft = df_reviews.groupby('tconst')['review'].count() \
    .value_counts() \
    .sort_index()
dft.plot.bar(ax=ax)
ax.set_title('Gráfico de barras de #Reseñas por película')

ax = axs[1]
dft = df_reviews.groupby('tconst')['review'].count()
sns.kdeplot(dft, ax=ax)
ax.set_title('Gráfico KDE de #Reseñas por película')

fig.tight_layout()

# %% [markdown]
# **Observaciones:**
#
# - **Existe una tendencia creciente** que se refleja en número de películas creadas cada año y el número de reseñas.
# - **La mayoría de las películas reciben pocas reseñas** de 1 a 5.
# - **Hay 30 películas que han recibido 400 reseñas**, estas pueden ser las películas más publicitadas y reseñadas para sus lanzamientos los cuales incluyen tanto critica como opiniones de usuarios.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Excelentes observaciones sobre la distribución de reseñas Sebastian!

# %%
df_reviews['pos'].value_counts()
# Out:
# 0    23715
# 1    23614
# Name: pos, dtype: int64

# %%
# analizo el % de cada clase para entrenmiento y prueba 
print(df_reviews.query('ds_part == "train"')['pos'].value_counts()/len(df_reviews.query('ds_part == "train"')))
df_reviews.query('ds_part == "test"')['pos'].value_counts()/len(df_reviews.query('ds_part == "test"'))
# Out:
# 0    0.500588
# 1    0.499412
# Name: pos, dtype: float64
# 0    0.501551
# 1    0.498449
# Name: pos, dtype: float64

# %%
# creo una gráfica para investigar el desbalanceo de clases
bar = sns.histplot(data=df_reviews, x='ds_part', hue='pos', multiple='stack', shrink=.6)
plt.xlabel('Entrenamiento - Prueba', fontsize=10)
plt.ylabel('Reseñas', fontsize=10)
plt.legend(title='', loc='upper center', labels=['Positiva', 'Negativa'])
plt.title('Distribución de reseñas para entrenamiento y prueba', fontsize=12)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

ax = axs[0]
dft = df_reviews.query('ds_part == "train"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('El conjunto de entrenamiento: distribución de puntuaciones')

ax = axs[1]
dft = df_reviews.query('ds_part == "test"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('El conjunto de prueba: distribución de puntuaciones')

fig.tight_layout()

# %% [markdown]
# **Observaciónes:**
#
# - Para las reseñas positivas y negativas en el conjunto de entrenamiento y prueba **existe una distribución similar.**
# - **Ambas concentran la mayoría de las reseñas en los extremos** y no hay valores de 5 o 6.
# - **Las clases están balanceadas en entrenamiento y prueba 50% positivas y 50% negativas.**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Continuamos y en este caso sobre las puntuaciones, vienes excelente Sebastian!

# %% [markdown]
# Distribución de reseñas negativas y positivas a lo largo de los años para dos partes del conjunto de datos

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 8), gridspec_kw=dict(width_ratios=(2, 1), height_ratios=(1, 1)))

ax = axs[0][0]

dft = df_reviews.query('ds_part == "train"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('El conjunto de entrenamiento: número de reseñas de diferentes polaridades por año')

ax = axs[0][1]

dft = df_reviews.query('ds_part == "train"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('El conjunto de entrenamiento: distribución de diferentes polaridades por película')

ax = axs[1][0]

dft = df_reviews.query('ds_part == "test"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('El conjunto de prueba: número de reseñas de diferentes polaridades por año')

ax = axs[1][1]

dft = df_reviews.query('ds_part == "test"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('El conjunto de prueba: distribución de diferentes polaridades por película')

fig.tight_layout()
# Out:
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Observaciones:**
#
# - En otra perspectiva podemos ver que **las reseñas para entrenamiento y prueba son muy similares a lo largo de los años.**
# - **La distribución de reseñas positivas es menos acentuada** y se concentra en el rango de 1 a 10 reseñas.
# - Por otra parte **la distribución de reseñas negativas se concentra en el rango 1-5 con mayor densidad.**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
#
# Quiero detenerme aquí Sebastian para felicitarte por el completo análisis que has hecho, tus conclusiones han sido correctas y no hubo mucho más que agregar, muy bien hecho!

# %% [markdown]
# ## Procedimiento de evaluación

# %% [markdown]
# Composición de una rutina de evaluación que se pueda usar para todos los modelos en este proyecto

# %%
import sklearn.metrics as metrics
def evaluate_model(model, train_features, train_target, test_features, test_target):
    
    eval_stats = {}
    
    fig, axs = plt.subplots(1, 3, figsize=(20, 6)) 
    
    for type, features, target in (('train', train_features, train_target), ('test', test_features, test_target)):
        
        eval_stats[type] = {}
    
        pred_target = model.predict(features)
        pred_proba = model.predict_proba(features)[:, 1]
        
        # F1
        f1_thresholds = np.arange(0, 1.01, 0.05)
        f1_scores = [metrics.f1_score(target, pred_proba>=threshold) for threshold in f1_thresholds]
        
        # ROC
        fpr, tpr, roc_thresholds = metrics.roc_curve(target, pred_proba)
        roc_auc = metrics.roc_auc_score(target, pred_proba)    
        eval_stats[type]['ROC AUC'] = roc_auc

        # PRC
        precision, recall, pr_thresholds = metrics.precision_recall_curve(target, pred_proba)
        aps = metrics.average_precision_score(target, pred_proba)
        eval_stats[type]['APS'] = aps
        
        if type == 'train':
            color = 'blue'
        else:
            color = 'green'

        # Valor F1
        ax = axs[0]
        max_f1_score_idx = np.argmax(f1_scores)
        ax.plot(f1_thresholds, f1_scores, color=color, label=f'{type}, max={f1_scores[max_f1_score_idx]:.2f} @ {f1_thresholds[max_f1_score_idx]:.2f}')
        # establecer cruces para algunos umbrales        
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(f1_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(f1_thresholds[closest_value_idx], f1_scores[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('threshold')
        ax.set_ylabel('F1')
        ax.legend(loc='lower center')
        ax.set_title(f'Valor F1') 

        # ROC
        ax = axs[1]    
        ax.plot(fpr, tpr, color=color, label=f'{type}, ROC AUC={roc_auc:.2f}')
        # establecer cruces para algunos umbrales        
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(roc_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'            
            ax.plot(fpr[closest_value_idx], tpr[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.plot([0, 1], [0, 1], color='grey', linestyle='--')
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.legend(loc='lower center')        
        ax.set_title(f'Curva ROC')
        
        # PRC
        ax = axs[2]
        ax.plot(recall, precision, color=color, label=f'{type}, AP={aps:.2f}')
        # establecer cruces para algunos umbrales        
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(pr_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(recall[closest_value_idx], precision[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('recall')
        ax.set_ylabel('precision')
        ax.legend(loc='lower center')
        ax.set_title(f'PRC')        

        eval_stats[type]['Accuracy'] = metrics.accuracy_score(target, pred_target)
        eval_stats[type]['F1'] = metrics.f1_score(target, pred_target)
    
    df_eval_stats = pd.DataFrame(eval_stats)
    df_eval_stats = df_eval_stats.round(2)
    df_eval_stats = df_eval_stats.reindex(index=('Exactitud', 'F1', 'APS', 'ROC AUC'))
    
    print(df_eval_stats)
    
    return

# %% [markdown]
# ## Normalización

# %% [markdown]
# Suponemos que todos los modelos a continuación aceptan textos en minúsculas y sin dígitos, signos de puntuación, etc.

# %%
#creo una funcion para limpiar las reseñas de caracteres no deseados 

def clean_text(text):
    # utilizo expresiones regulares para remplazar por '' lo <> a letras min y mayúsculas
    pattern = r'[^a-zA-z\']'
    clean_text = re.sub(pattern, ' ', text)
    
    # utilizo join y luego split para deshacer espacios indeseados, y luego uso lower()
    clean_text = " ".join(clean_text.split())
    clean_text = clean_text.lower()
    
    return clean_text

# %%
# utilizo la funcion clean_text para normalizar el texto y crear la columna 'review_norm' 
df_reviews['review_norm'] = df_reviews['review'].apply(lambda x:clean_text(x))

# %%
# verifico los resultados
df_reviews['review_norm'].head()
# Out:
# 0    the pakage implies that warren beatty and gold...
# 1    how the hell did they get this made presenting...
# 2    there is no real story the film seems more lik...
# 3    um a serious film about troubled teens in sing...
# 4    i'm totally agree with garryjohal from singapo...
# Name: review_norm, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
#
# Excelente creación de la función encargada de limpiear y normalizar nuestro corpus de datos, a la vez excelente implementación de la misma, bien hecho!

# %% [markdown]
# **Observación:** Se normalizaron los datos con el uso de la función clean_text, esta utiliza expresiones regulares y el uso de split y join para limpiar las reseñas de caracteres y espacios no deseados.

# %% [markdown]
# ## División entrenamiento / prueba

# %% [markdown]
# Por fortuna, todo el conjunto de datos ya está dividido en partes de entrenamiento/prueba; 'ds_part' es el indicador correspondiente.

# %%
# extraer las reseñas para entenamiento y para prueba
df_reviews_train = df_reviews.query('ds_part == "train"').copy()
df_reviews_test = df_reviews.query('ds_part == "test"').copy()

# extraer el objetivo de prediccón para entrenamiento y prueba
train_target = df_reviews_train['pos']
test_target = df_reviews_test['pos']

# %%
# verifico el tamaño de los segmentos de prueba
print('features_train:', df_reviews_train.shape)
print('target_train:', train_target.shape)
print('')
print('features_test:', df_reviews_test.shape)
print('target_test:', test_target.shape)
# Out:
# features_train: (23796, 18)
# target_train: (23796,)
#
# features_test: (23533, 18)
# target_test: (23533,)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Partimos los datos en los conjuntos de entrenamiento y testeo. Bien,sigamos!

# %% [markdown]
# **Observaciones:**
#
# - Los tamaños de cada segmento corresponden a **50% para entrenamiento y 50% prueba.**
# - Los segmentos de características tienen las columnas: `tconst`, `title_type`, `primary_title`, `original_title`, `start_year`, `end_year`, `runtime_minutes`, `is_adult`, `genres`, `average_rating`, `votes`, **`review`**, `rating`, `sp`, `pos`, `ds_part` y `idx`
# - **(Solor se usará `review` para las predicciones.)**
#
# - Los segmentos de objetivo solo tienen la columna `pos`.

# %% [markdown]
# ## Trabajar con modelos

# %% [markdown]
# ### Modelo 1 - Constante

# %%
#creo model_0 para dummy clasiffier
model_0 = DummyClassifier(strategy='constant', constant = 1, random_state=300)
model_0.fit(df_reviews_train, train_target)
# Out:
# DummyClassifier(constant=1, random_state=300, strategy='constant')

# %%
evaluate_model(model_0, df_reviews_train, train_target, df_reviews_test, test_target)
# Out:
#            train  test
# Exactitud    NaN   NaN
# F1          0.67  0.67
# APS         0.50  0.50
# ROC AUC     0.50  0.50

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Aquí la estructura es correcta Sebastian, sin embargo debemos corregir unos detalles. El querer un modelo constante nos indica que como valor de strategy tomemos **constant** en vez de **stratified**, a la vez esto nos implicaria agregar el parametro **cosntant=1**. Con este simple cambio deberíamos obtener lo correcto.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 2)</b> <a class="tocSkip"></a>
#
# Excelente implementación de lo solicitado Sebastian, felicitaciones!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta Estudiante</b>
#
# Gracias Facundo, utilizo 'constant' como strategy, agrego el parámetro constant = 1 y actualizo los resultados.
#
# <a class="tocSkip"></a>
# </div>

# %% [markdown]
# - El valor de **F1 es 0.67**, no es una valor alto pero servirá como base para la comparación de otros modelos.
# - **El área bajo la curva ROC 0.5 representa el uso del azar** para cada resultado.
# - la curva **precisión/recall es 0.5** para el modelo dummy

# %% [markdown]
# ### Modelo 2 - NLTK, TF-IDF y LR

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#defino lemmatizer con wnl de NLTK
lemmatizer = WordNetLemmatizer()

#creo la función para usar word_tokenize y luego lemmatize
def NLTK_Token_Lemma(text):
    words_tokenized = word_tokenize(text)
    words_lemmatized = [lemmatizer.lemmatize(word) for word in words_tokenized]
    
    return " ".join(words_lemmatized)

# %%
features_train_NLTK = df_reviews_train['review_norm'].progress_apply(NLTK_Token_Lemma)
features_test_NLTK = df_reviews_test['review_norm'].progress_apply(NLTK_Token_Lemma)
# Out:
# ...
#   0%|          | 0/23533 [00:00<?, ?it/s]

# %%
#verifico la tokenización y lematización con NLTK
print('Original:', df_reviews_train['review_norm'][47257])
print('')
print('Lematizado:', features_train_NLTK[47257])
# Out:
# Original: as a history nut who is particularly interested in this particular historical event i was very disappointed with the movie granted the costumes and staging was quite authentic but the hollywood portrayal of this british little big horn was truly boring the amount of film footage dedicated to marching or parading troops has to have been unprecedented in film history eveytime i heard triumphant background music begin i knew i had to prepare myself for another laborious scene of meaningless filler obviously the producers had invested heavily into staging and were determined to get their money's worth despite the outstanding cast their dialogue was again boring and their characters were never developed whenever peter o'toole or burt lancaster finished a scene i would cringe with disappointment their given lines were so weak and meaningless that i could hardly believe these were the same two great actors who portrayed lawrence of arabia and the bird man of alcatraz respectively 
# ...

# %%
#creo corpus = a reseñas normalizadas y creo stop_words
corpus = features_train_NLTK
stop_words = set(stopwords.words('english'))

#defino en tf-tdi stopword english
tfidf_vectorizer_2 = TfidfVectorizer(stop_words=stop_words) 
tfidf_vectorizer_2.fit_transform(corpus)

# creo train y test fetures 2 con el uso de .transform
train_features_2 = tfidf_vectorizer_2.transform(features_train_NLTK)
test_features_2 = tfidf_vectorizer_2.transform(features_test_NLTK)

# %%
# creo el modelo de regresion logistica
model_2 = LogisticRegression(solver='liblinear', random_state=300)
model_2.fit(train_features_2, train_target)
# Out:
# LogisticRegression(random_state=300, solver='liblinear')

# %%
evaluate_model(model_2, train_features_2, train_target, test_features_2, test_target)
# Out:
#            train  test
# Exactitud    NaN   NaN
# F1          0.94  0.88
# APS         0.98  0.95
# ROC AUC     0.98  0.95

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Aquí el procedimiento es muy correcto Sebastián, tanto el filtrado de stopwords, la vectorización, el entrenamiento y evaluación, lo has hecho muy bien! Sin embargo, se nos ha olvidado agregar el procedimiento de tokenización y lemmatización con NLTK, te recomiendo agregar una función que tome nuestro corpus y se encargue de este proceso, luego ya se debe acoplar a lo ya implementado.
#
#     Implementación perfecta nuevamente! Bien hecho!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta Estudiante</b>
#
# Gracias Facundo, creo la función 'NLTK_Token_Lemma' para realizar la tokenización y lematización con NLTK para completar este modelo y actualizo los resultados.
#
# <a class="tocSkip"></a>
# </div>

# %% [markdown]
# - El valor de **F1 es 0.88**, el uso de NLTK y Tf-Idf mejoró notablemente las predicciones del modelo: esto se debe a que NLTK permite tokenizar, lematizar y usar stopwords, y Tf-Idf permite vectorizar y asignar importancia a las palabras, de esta forma el modelo de regresión logística es mucho más preciso en sus predicciones.
#
# - **El área bajo la curva es ROC 0.95:** podemos ver que la curva se inclina a la izquierda lo que lo aleja del azar y los acerca al valor máximo posible.
#
# - la curva **precisión/recall también mejoró a 0.95**

# %% [markdown]
# ### Modelo 3 - spaCy, TF-IDF y LR

# %%
#uso spacy y agrego la libreria en_core_web_sm
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def text_preprocessing_3(text):
    
    doc = nlp(text)
    #tokens = [token.lemma_ for token in doc if not token.is_stop]
    tokens = [token.lemma_ for token in doc]
    
    return ' '.join(tokens)

# %%
# creo features y test 3 con el uso de la funcion text processing ** tiempo estimado 18 mins
features_train_spacy = df_reviews_train['review_norm'].progress_apply(text_preprocessing_3)
features_test_spacy = df_reviews_test['review_norm'].progress_apply(text_preprocessing_3)
# Out:
# ...
#   0%|          | 0/23533 [00:00<?, ?it/s]

# %%
#creo corpus = a reseñas lematizadas
corpus = features_train_spacy

#creo vectorized_3 para almacenar tfidf lematizados
tfidf_vectorizer_3 = TfidfVectorizer() 
tfidf_vectorizer_3.fit_transform(corpus)

# creo train y test fetures 3 con el uso de .transform
train_features_3 = tfidf_vectorizer_3.transform(features_train_spacy)
test_features_3 = tfidf_vectorizer_3.transform(features_test_spacy)

# %%
# creo el modelo de regresión logista y lo entreno con features_3
model_3 = LogisticRegression(solver='liblinear', random_state=300)
model_3.fit(train_features_3, train_target)
evaluate_model(model_3, train_features_3, train_target, test_features_3, test_target)
# Out:
#            train  test
# Exactitud    NaN   NaN
# F1          0.93  0.88
# APS         0.98  0.95
# ROC AUC     0.98  0.95

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Implementación similar a la atnerior pero utilizando los datos preprocesados con la función de spacy, excelente!

# %% [markdown]
# - El valor de **F1 es 0.88**, el uso de spacy y Tf-idf obtuvo los mismos resultados que la anterior regresión logística, sin embargo, el proceso de lematización es muy lento ~18 mins, si no se cuenta con una GPU.
#
# - **El área bajo la curva ROC es 0.95,** podemos ver que de igual forma la curva se inclina a la izquierda lo que lo aleja del azar y los acerca al valor máximo posible.
#
# - la curva **precisión/recall es igual a 0.95**

# %% [markdown]
# ### Modelo 4 - spaCy, TF-IDF y LGBMClassifier

# %%
# utilizo el mismo spacy del punto anterior como mismas características
train_features_4 = train_features_3
test_features_4 = test_features_3

# %%
# creo el modelo de lightGBM 
model_4 = LGBMClassifier(boosting_type='gbdt', 
                         num_leaves=31, 
                         max_depth=-1, 
                         learning_rate=0.3, 
                         n_estimators=100, 
                         random_state=300)

# entreno el modelo con train_fatures_4
model_4.fit(train_features_4, train_target)
evaluate_model(model_4, train_features_4,  train_target , test_features_4, test_target)
# Out:
#            train  test
# Exactitud    NaN   NaN
# F1          0.99  0.87
# APS         1.00  0.94
# ROC AUC     1.00  0.94

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Resultados nuevamente perfectos Sebastian!

# %% [markdown]
# - El valor de **F1 disminuyó a 0.87**, el uso de spacy y Tf-idf en modelo LightGBM otorga métricas menos favorables que el uso en regresión logística.
#
# - **El área bajo la curva ROC es 0.94** y la curva **precisión/recall es 0.94**
#
# - Además se nota mayor diferencia entre las métricas de entrenamiento/prueba, lo cual sugiere que el modelo de lightGBM está sobre ajustado.

# %%
###  Modelo 9 - BERT

# %% [markdown]
# **Opcional** - en esta ocasión no utilizare BERT debido a capacidad de procesamiento, sin embargo mantengo el Código como comentario

# %%
#import torch
#import transformers

# %%
#tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-uncased')
#config = transformers.BertConfig.from_pretrained('bert-base-uncased')
#model = transformers.BertModel.from_pretrained('bert-base-uncased')

# %%
# def BERT_text_to_embeddings(texts, max_length=512, batch_size=100, force_device=None, disable_progress_bar=False):
    
#     ids_list = []
#     attention_mask_list = []

#     # texto al id de relleno de tokens junto con sus máscaras de atención 
       
#     # <escribe tu código aquí para crear ids_list y attention_mask_list>
    
#     if force_device is not None:
#         device = torch.device(force_device)
#     else:
#         device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
#     model.to(device)
#     if not disable_progress_bar:
#         print(f'Uso del dispositivo {device}.')
    
#     # obtener insertados en lotes
    
#     embeddings = []

#     for i in tqdm(range(math.ceil(len(ids_list)/batch_size)), disable=disable_progress_bar):
            
#         ids_batch = torch.LongTensor(ids_list[batch_size*i:batch_size*(i+1)]).to(device)
#         # <escribe tu código aquí para crear attention_mask_batch
            
#         with torch.no_grad():            
#             model.eval()
#             batch_embeddings = model(input_ids=ids_batch, attention_mask=attention_mask_batch)   
#         embeddings.append(batch_embeddings[0][:,0,:].detach().cpu().numpy())
        
#     return np.concatenate(embeddings)

# %%
# ¡Atención! La ejecución de BERT para miles de textos puede llevar mucho tiempo en la CPU, al menos varias horas
# train_features_9 = BERT_text_to_embeddings(df_reviews_train['review_norm'], force_device='cuda')

# %%
# print(df_reviews_train['review_norm'].shape)
# print(train_features_9.shape)
# print(train_target.shape)

# %%
# si ya obtuviste los insertados, te recomendamos guardarlos para tenerlos listos si
# np.savez_compressed('features_9.npz', train_features_9=train_features_9, test_features_9=test_features_9)

# y cargar...
# with np.load('features_9.npz') as data:
#     train_features_9 = data['train_features_9']
#     test_features_9 = data['test_features_9']

# %%
#creo un dataframe para los resultados
model_compare = pd.DataFrame({
    'modelo':['Dummy', 'NLTK, TF-IDF y LR', 'spaCy, TF-IDF y LR', 'spaCy, TF-IDF y LGBM'],
    'F1':[0.67, 0.88, 0.88, 0.87],
    'APS':[0.5, 0.95, 0.95, 0.94],
    'ROC':[0.5,0.95,0.95, 0.94]
    }
)

model_compare = model_compare.sort_values(by='F1', ascending= False )
model_compare
# Out:
#                  modelo    F1   APS   ROC
# 1     NLTK, TF-IDF y LR  0.88  0.95  0.95
# 2    spaCy, TF-IDF y LR  0.88  0.95  0.95
# 3  spaCy, TF-IDF y LGBM  0.87  0.94  0.94
# 0                 Dummy  0.67  0.50  0.50

# %%
# creo una dataframe para comparar los modelos por RMSE
model_compare = model_compare.sort_values(by='F1', ascending= False)
model_compare

# creo subplots para graficar RMSE vs tiempo de entrenamiento
fig, ax1 = plt.subplots(figsize=(12, 6))

# defino los colores para la grafica
colors = ['#4169e1', '#4169e1', '#d3d3d3', '#d3d3d3']


# gráfico el RMSE para cada modelo de barras 
sns.barplot(x='modelo', 
           y='F1', 
           palette = colors,
           data=model_compare,
           ax=ax1, 
           alpha = 0.8) 


ax1.set_ylim(0,1)                                      #defino el limite del eje 1

plt.title("¿Cuál es el mejor modelo: Mayor F1?")    #asigno un titulo
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Excelente muestrei de los resultados Sebastian, simplemente recordemos modificar el primer modelo agregandole la función de lemmatizacion y tokenizacion.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta Estudiante</b>
#
# Actualizo los resultados luego de modificar el modelo NLTK, TFIDF y LR, afortunadamente sigue siendo el modelo recomendado.
#
# <a class="tocSkip"></a>
# </div>

# %% [markdown]
# **Observaciónes:**
#
# - Los **modelos que maximizan el F1 son `NLTK, TF-IDF y LR` y `spaCy, TF-IDF y LR` con 0.88**
#
# - No obstante, **`spaCy, TF-IDF y LR` es un modelo que requiere mucho tiempo para lematizar las reseñas en el entrenamiento**, casi ~18 mis, lo cual lo hace menos atractivo por su rendimiento.
#
# - **Podemos ver que el mejor modelo para la compañía es `NLTK, TF-IDF y LR`** dada su precisión y velocidad, sera el recomendado para la compañía.

# %% [markdown]
# ## Mis reseñas

# %%
# puedes eliminar por completo estas reseñas y probar tus modelos en tus propias reseñas; las que se muestran a continuación son solo ejemplos
# agregue algunas de las reseñas reales para la pelicula the shawshank redemption

my_reviews = pd.DataFrame([
    'I have lost count of the number of times I have seen this movie, but it is more than 20. It has to be one of the best movies ever made. It made me take notice Morgan Freeman and Tim Robbins like I had never noticed any actors before.'
    'I did not simply like it, not my kind of movie.',
    'Well, I was bored and felt asleep in the middle of the movie.',
    'I was really fascinated with the movie',    
    'Even the actors looked really old and disinterested, and they got paid to be in the movie. What a soulless cash grab.',
    'I didn\'t expect the reboot to be so good! Writers really cared about the source material',
    'The movie had its upsides and downsides, but I feel like overall it\'s a decent flick. I could see myself going to see it again.',
    'What a rotten attempt at a comedy. Not a single joke lands, everyone acts annoying and loud, even kids won\'t like this!',
    'Launching on Netflix was a brave move & I really appreciate being able to binge on episode after episode, of this exciting intelligent new drama.',
    'This is the worst movie I have ever seen. Its so Hollywood cliche ! How can this be in the top 2 best movies ever ? I do not understand it. Avoid at all cost, this movie is boring !'],
    columns=['review'])

"""
my_reviews = pd.DataFrame([
    'Simplemente no me gustó, no es mi tipo de película.',
    'Bueno, estaba aburrido y me quedé dormido a media película.',
    'Estaba realmente fascinada con la película',    
    'Hasta los actores parecían muy viejos y desinteresados, y les pagaron por estar en la película. Qué robo tan desalmado.',
    '¡No esperaba que el relanzamiento fuera tan bueno! Los escritores realmente se preocuparon por el material original',
    'La película tuvo sus altibajos, pero siento que, en general, es una película decente. Sí la volvería a ver',
    'Qué pésimo intento de comedia. Ni una sola broma tiene sentido, todos actúan de forma irritante y ruidosa, ¡ni siquiera a los niños les gustará esto!',
    'Fue muy valiente el lanzamiento en Netflix y realmente aprecio poder seguir viendo episodio tras episodio de este nuevo drama tan emocionante e inteligente.'
], columns=['review'])
"""
# Out:
# "\nmy_reviews = pd.DataFrame([\n    'Simplemente no me gustó, no es mi tipo de película.',\n    'Bueno, estaba aburrido y me quedé dormido a media película.',\n    'Estaba realmente fascinada con la película',    \n    'Hasta los actores parecían muy viejos y desinteresados, y les pagaron por estar en la película. Qué robo tan desalmado.',\n    '¡No esperaba que el relanzamiento fuera tan bueno! Los escritores realmente se preocuparon por el material original',\n    'La película tuvo sus altibajos, pero siento que, en general, es una película decente. Sí la volvería a ver',\n    'Qué pésimo intento de comedia. Ni una sola broma tiene sentido, todos actúan de forma irritante y ruidosa, ¡ni siquiera a los niños les gustará esto!',\n    'Fue muy valiente el lanzamiento en Netflix y realmente aprecio poder seguir viendo episodio tras episodio de este nuevo drama tan emocionante e inteligente.'\n], columns=['review'])\n"

# %%
#creo una lista vacía para almacenar los resultados normalizados
review_norm = []

#creo un for para iterar por cada comentario
for row in my_reviews['review']:
    
    #ejecuto la misma funcion que utilice anteriormente
    review_norm.append(clean_text(row))    

# creo review_norm con las reseñas limpias
my_reviews['review_norm'] = review_norm    

my_reviews
# Out:
#                                               review  \
# 0  I have lost count of the number of times I hav...
# 1  Well, I was bored and felt asleep in the middl...
# 2             I was really fascinated with the movie
# 3  Even the actors looked really old and disinter...
# 4  I didn't expect the reboot to be so good! Writ...
# 5  The movie had its upsides and downsides, but I...
# 6  What a rotten attempt at a comedy. Not a singl...
# 7  Launching on Netflix was a brave move & I real...
# 8  This is the worst movie I have ever seen. Its ...
#
#                                          review_norm
# 0  i have lost count of the number of times i hav...
# 1  well i was bored and felt asleep in the middle...
# 2             i was really fascinated with the movie
# 3  even the actors looked really old and disinter...
# 4  i didn't expect the reboot to be so good write...
# 5  the movie had its upsides and downsides but i ...
# 6  what a rotten attempt at a comedy not a single...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Excelentes Reviews Sebastan!

# %% [markdown]
# ### Modelo 2 - NLTK, TF-IDF y LR

# %%
# almaceno mis reseñas en texts
texts = my_reviews['review_norm']

#utilizo el modelo 2 para predecir con tftdf y transform en review_norm 
my_reviews_pred_prob = model_2.predict_proba(tfidf_vectorizer_2.transform(texts))[:, 1]

#imprimo el resultado de predicción y la reseña
for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.65:  i have lost count of the number of times i have seen this movie but it is more than it has to be one
# 0.18:  well i was bored and felt asleep in the middle of the movie
# 0.58:  i was really fascinated with the movie
# 0.17:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.39:  i didn't expect the reboot to be so good writers really cared about the source material
# 0.49:  the movie had its upsides and downsides but i feel like overall it's a decent flick i could see myse
# 0.09:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.89:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo
# 0.06:  this is the worst movie i have ever seen its so hollywood cliche how can this be in the top best mov

# %% [markdown]
# ### Modelo 3 - spaCy, TF-IDF y LR

# %%
texts = my_reviews['review_norm']

#utilizo el modelo 3 para predecir con tftdf y transform en review_norm
my_reviews_pred_prob = model_3.predict_proba(tfidf_vectorizer_3.transform(texts.apply(lambda x: text_preprocessing_3(x))))[:, 1]

#imprimo el resultado de predicción y la reseña
for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.59:  i have lost count of the number of times i have seen this movie but it is more than it has to be one
# 0.20:  well i was bored and felt asleep in the middle of the movie
# 0.49:  i was really fascinated with the movie
# 0.14:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.19:  i didn't expect the reboot to be so good writers really cared about the source material
# 0.68:  the movie had its upsides and downsides but i feel like overall it's a decent flick i could see myse
# 0.04:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.87:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo
# 0.08:  this is the worst movie i have ever seen its so hollywood cliche how can this be in the top best mov

# %% [markdown]
# ### Modelo 4 - spaCy, TF-IDF y LGBMClassifier

# %%
texts = my_reviews['review_norm']

# utilizo el modelo 4 para predecir con tftdf y transform en review_norm
tfidf_vectorizer_4 = tfidf_vectorizer_3
my_reviews_pred_prob = model_4.predict_proba(tfidf_vectorizer_3.transform(texts.apply(lambda x: text_preprocessing_3(x))))[:, 1]

# imprimo el resultado de predicción y la reseña 
for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.86:  i have lost count of the number of times i have seen this movie but it is more than it has to be one
# 0.38:  well i was bored and felt asleep in the middle of the movie
# 0.57:  i was really fascinated with the movie
# 0.42:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.17:  i didn't expect the reboot to be so good writers really cared about the source material
# 0.87:  the movie had its upsides and downsides but i feel like overall it's a decent flick i could see myse
# 0.19:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.91:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo
# 0.04:  this is the worst movie i have ever seen its so hollywood cliche how can this be in the top best mov

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Implementaciones y resultados perfectos Sebastian! Bien hecho!

# %%
### Modelo 9

# %%
# texts = my_reviews['review_norm']

# my_reviews_features_9 = BERT_text_to_embeddings(texts, disable_progress_bar=True)

# my_reviews_pred_prob = model_9.predict_proba(my_reviews_features_9)[:, 1]

# for i, review in enumerate(texts.str.slice(0, 100)):
#     print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')

# %% [markdown]
# **Observaciones:**
#
# - **Se puedo conocer las predicciones de cada modelo** para las nuevas reseñas.
# - **Existen rangos similares para las valoraciones**, sin embargo, existen casos como en la reseña 2 el modelo de LGBM = 0.38 vs NLTK, TF-IDF y LR = 0.16, para la misma reseña, lightGMB tiende a diferenciarse de los otros dos modelos.
# - **las valoraciones de NLTK, TF-IDF y LR y spaCy, TF-IDF y LR son generalmente similares**, solo tienen algunos casos donde existe una variación mayor.

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# **Se recomienda a la compañía implementar el modelo de NLTK, TF-IDF y LR, ya que este maximiza el valor F1 en la clasificacion de las reseñas.**
#
# Esto se debe a que NLTK permite usar stopwords (limpiando el texto), y Tf-Idf permite vectorizar y asignar importancia a las palabras, de esta forma el modelo de regresión logística es mucho más preciso.
#
# - F1: 0.88
# - APS: 0.95
# - ROC AUC: 0.95
#
# ________________________________________________________________________
# **Resumen del proyecto:**
#
# **1) Extracción y preparación de datos:**
# En primer lugar se analizaron los datos sobre las reseñas:
#
# - Se eliminaron valores ausentes.
# - No se encontraron valores duplicados.
#
# **2) Exploración de datos**
#
# - **Existe una tendencia creciente** en el número de películas y el número de reseñas por año.
# - **La mayoría de las películas reciben pocas reseñas**.
# - **Ambas concentran la mayoría de las reseñas en los extremos** y no hay valores de 5 o 6.
# - **Las clases están balanceadas en entrenamiento y prueba  50% positiva y 50% negativa.**
# - Para las reseñas positivas y negativas en el set de entrenamiento y prueba **existe una distribución similar.**
#
# **3) Procedimiento de evaluación**
# - Se definió una funcion para evaluar los resultados de los modelos.
#
# **4) Normalización**
# - Se creó una función para normalizar las reseñas, limpiando el texto con el uso de expresiones regulares, replace y join.
#
# **5) División Entrenamiento y prueba**
#
# - Los tamaños de cada segmento corresponden a **50% para entrenamiento y 50% prueba.**
# - Los segmentos de características tienen varias columnas: donde se utilizó `review` para extraer las reseñas.
# - Los segmentos de objetivo solo tienen la columna `pos`.
#
# **6) Trabajar con modelos**
#
# - Los **modelos que maximizan el F1 son `NLTK, TF-IDF y LR` y `spaCy, TF-IDF y LR` con 0.88**
# - No obstante, **`spaCy, TF-IDF y LR` es un modelo que requiere mucho tiempo para lematizar las reseñas en el entrenamiento.**
#
# - **Podemos ver que el mejor modelo para la compañía es `NLTK, TF-IDF y LR`** dada su precisión y velocidad.
# - **En este proyecto no se incluyó BERT** debido a capacidad de procesamiento.
#
# **7) Mis reseñas**
#
# - Se probaron los diferentes modelos con reseñas nuevas y se analizó las similitudes y deferencias.
#
# - **Existen rangos similares para las valoraciones.**
# - **Las valoraciones de NLTK, TF-IDF y LR y spaCy, TF-IDF y LR son generalmente similares**, LightGMB difiere en comparación.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Una conclusión que demuestra la comprensión de lo hecho a lo largo del trabajo, bien hecho Sebastian! Destaco tu compromiso no solo en esta conclusión final sino en aquellas intermedias durante el trabajo, a nivel general lo has hecho excelente!

# %% [markdown]
# # Lista de comprobación

# %% [markdown]
# - [x]  Abriste el notebook
# - [x]  Cargaste y preprocesaste los datos de texto para su vectorización
# - [x]  Transformaste los datos de texto en vectores
# - [x]  Entrenaste y probaste los modelos
# - [x]  Se alcanzó el umbral de la métrica
# - [x]  Colocaste todas las celdas de código en el orden de su ejecución
# - [X]  Puedes ejecutar sin errores todas las celdas de código
# - [X]  Hay conclusiones
